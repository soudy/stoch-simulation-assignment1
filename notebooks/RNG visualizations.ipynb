# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from Function import uniform_sampler, latin_square_sampler, orthogonal_sampler

mpl.rcParams["figure.dpi"] = 200
mpl.rcParams["legend.fontsize"] = 11
mpl.rcParams["font.size"] = 11
plt.rc("text", usetex=True)
plt.rc("text.latex", preamble=r"""
 \usepackage{palatino}
 \usepackage{newpxmath}""")
plt.rc("font", family="serif")

n = 30
lows = (0, 0)
highs = (1, 1)

# %%
from numpy.random import Generator, MT19937

# %%
rng = Generator(MT19937(2412))

pure_random = uniform_sampler(rng, lows, highs, n)
x, y = pure_random.T

plt.figure(figsize=(4.5, 4))
plt.scatter(x, y, color="black", s=3)
plt.title("Pure Random Sampling")

plt.xticks([])
plt.yticks([])

plt.xlim(0, 1)
plt.ylim(0, 1)
plt.savefig('figures/pure_random_sampling.pdf', bbox_inches='tight')
plt.show()

# %%
rng = Generator(MT19937(2412))
pure_random = latin_square_sampler(rng, lows, highs, n)
x, y = pure_random.T

minor_ticks_top = np.linspace(0, 1, 40)

fig, ax = plt.subplots(figsize=(4.5, 4))

ax.set_xticks(minor_ticks_top,minor=True)
ax.set_yticks(minor_ticks_top , minor=True)
ax.grid(which="minor", alpha=0.6, zorder=0)

ax.set_xticklabels([])
ax.set_yticklabels([])


ax.scatter(x, y, color="black", s=3, zorder=2)
ax.set_title("Latin Hypercube Sampling")
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
plt.savefig('figures/lhs_sampling.pdf', bbox_inches='tight')
plt.show()

# %%
orthogonal_sampler(rng, (-2, -1.12), (1, 1.12), n)
# Out:
# array([[-1.89344902e+00, -8.56593433e-01],
#        [-1.77740704e+00, -5.11098033e-01],
#        [-1.51737803e+00, -1.24174130e-01],
#        [-1.73662740e+00,  7.22448844e-02],
#        [-1.65679921e+00,  9.34770005e-01],
#        [-1.08605451e+00, -9.43919910e-01],
#        [-1.20945297e+00, -2.98509599e-01],
#        [-1.39338593e+00,  3.86924232e-02],
#        [-1.06334103e+00,  4.23026752e-01],
#        [-1.49232466e+00,  1.06601767e+00],
#        [-6.13647265e-01, -1.10352693e+00],
#        [-7.86086977e-01, -4.08577735e-01],
#        [-9.82295210e-01,  1.35167904e-01],
#        [-8.48334487e-01,  5.27671354e-01],
#        [-7.40684162e-01,  1.04070554e+00],
#        [-4.52204347e-01, -9.20160495e-01],
#        [-9.17400384e-02, -7.13685505e-01],
#        [-5.42203574e-02, -1.12519955e-03],
#        [-3.87660198e-01,  2.02402822e-01],
#        [-3.04337673e-01,  7.45605908e-01],
#        [-2.17022072e-01,  8.12642400e-01],
#        [ 3.28595073e-01, -6.01246207e-01],
#        [ 1.27949452e-01, -2.40735407e-01],
#        [ 2.47578552e-01,  6.52527036e-01],
#        [ 5.44495310e-02,  7.89442884e-01],
#        [ 8.12474795e-01, -1.05090816e+00],
#        [ 9.44890900e-01, -3.58549700e-01],
#        [ 6.31354857e-01,  3.60315134e-01],
#        [ 5.38949587e-01,  6.04032584e-01],
#        [ 6.70097669e-01,  9.10142394e-01]])

# %%
from matplotlib import ticker

rng = Generator(MT19937(888))
ortho = orthogonal_sampler(rng, lows, highs, n)
x, y = ortho.T

minor_ticks_top = np.arange(0, 37, 1)/36
major_ticks_top = np.arange(0, 37, 6)/36

fig, ax = plt.subplots(figsize=(4.5, 4))

ax.set_xticks(major_ticks_top)
ax.set_yticks(major_ticks_top)
ax.set_xticks(minor_ticks_top, minor=True)
ax.set_yticks(minor_ticks_top , minor=True)
ax.grid(which="major", alpha=0.8, zorder=0)
ax.grid(which="minor", alpha=0.2, zorder=0)

ax.set_xticklabels([])
ax.set_yticklabels([])

ax.scatter(x, y, color="black", s=3, zorder=2)
ax.set_title("Orthogonal Sampling")
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
plt.savefig('figures/ortho_sampling.pdf', bbox_inches='tight')
plt.show()
